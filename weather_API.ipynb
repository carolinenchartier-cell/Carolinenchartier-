# %% [markdown]
# <a href="https://colab.research.google.com/github/carolinenchartier-cell/Carolinenchartier-/blob/main/weather_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# Your API key here
API_KEY = "a81a4e774762f35853bb8228890886b7"

# City name
city = "Tokyo"

# API URL
url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"

# Make request
response = requests.get(url)

# Convert to JSON
data = response.json()

# Extract information
temperature = data["main"]["temp"]
humidity = data["main"]["humidity"]
country = data["sys"]["country"]

# Display result
print(f"It is currently {temperature}ºC in {city}, {country} and the humidity level is {humidity}%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3866/1712941594.py in <cell line: 0>()
#      17
#      18 # Extract information
# ---> 19 temperature = data["main"]["temp"]
#      20 humidity = data["main"]["humidity"]
#      21 country = data["sys"]["country"]
#
# KeyError: 'main'
